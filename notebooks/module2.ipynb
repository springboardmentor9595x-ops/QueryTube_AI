# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hemanth sai\onedrive\desktop\info\queytube\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("raw_metadata.csv")
print(df.info())

print("Dataset Shape:", df.shape)

print("First 5 rows:")
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      1000 non-null   str
#  1   title         1000 non-null   str
#  2   publish_date  1000 non-null   str
# dtypes: str(3)
# memory usage: 23.6 KB
# None
# Dataset Shape: (1000, 3)
# First 5 rows:
#       video_id                                              title  \
# 0  cw02dMpWStI  How to find good open source projects to contr...
# 1  0WjfKQdfeMU  NVIDIA-Certified Associate AI Infrastructure a...
# 2  ZldNCx4AvEM  Learn the basics of Git in 60 seconds with Bea...
# 3  E7o_WdfKszU  There's so much to learn - so how do you focus...
# 4  IBTx5aGj-6U  Build Your Own Video Sharing App – Loom Clone ...
#
#                 publish_date
# 0  2026-03-04 13:29:25+00:00
# 1  2026-03-04 11:00:02+00:00
# 2  2026-03-03 13:05:25+00:00
# 3  2026-03-02 13:17:28+00:00
# 4  2026-03-02 11:00:33+00:00

# %%
print("Column Names:", df.columns.tolist())
print("\nData Types:")
print(df.dtypes)
print("\nTotal Rows:", len(df))
# Out:
# Column Names: ['video_id', 'title', 'publish_date']
#
# Data Types:
# video_id        str
# title           str
# publish_date    str
# dtype: object
#
# Total Rows: 1000

# %%
print("Duplicate video_id:", df["video_id"].duplicated().sum())
print("Duplicate titles:", df["title"].duplicated().sum())
#if any duplicates are found in dataset
df = df.drop_duplicates(subset="video_id")
print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate video_id: 0
# Duplicate titles: 2
# Shape after removing duplicates: (1000, 3)

# %%
print("Missing values:\n")
df.isnull().sum()
# Out:
# Missing values:
# video_id        0
# title           0
# publish_date    0
# dtype: int64

# %%
df = df.dropna(subset=["video_id", "title", "publish_date"])
print("Shape after removing nulls:", df.shape)
# Out:
# Shape after removing nulls: (1000, 3)

# %%
df["publish_date"] = pd.to_datetime(df["publish_date"], errors="coerce")

df["year"] = df["publish_date"].dt.year
df["month"] = df["publish_date"].dt.month

df.head()
# Out:
#       video_id                                              title  \
# 0  cw02dMpWStI  How to find good open source projects to contr...
# 1  0WjfKQdfeMU  NVIDIA-Certified Associate AI Infrastructure a...
# 2  ZldNCx4AvEM  Learn the basics of Git in 60 seconds with Bea...
# 3  E7o_WdfKszU  There's so much to learn - so how do you focus...
# 4  IBTx5aGj-6U  Build Your Own Video Sharing App – Loom Clone ...
#
#                publish_date  year  month
# 0 2026-03-04 13:29:25+00:00  2026      3
# 1 2026-03-04 11:00:02+00:00  2026      3
# 2 2026-03-03 13:05:25+00:00  2026      3
# 3 2026-03-02 13:17:28+00:00  2026      3
# 4 2026-03-02 11:00:33+00:00  2026      3

# %%
videos_per_year = df.groupby("year").size()
videos_per_year
# Out:
# year
# 2021     97
# 2022    141
# 2023    180
# 2024    224
# 2025    264
# 2026     94
# dtype: int64

# %%
videos_per_year.plot(kind="bar", title="Video Uploads Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Videos")
plt.tight_layout()
plt.show()

# %%
videos_per_month = df.groupby("month").size()
videos_per_month
# Out:
# month
# 1     111
# 2     106
# 3      73
# 4      60
# 5      64
# 6      72
# 7      72
# 8      84
# 9      77
# 10    100
# 11     99
# 12     82
# dtype: int64

# %% [markdown]
# Title Analysis

# %%
df["title"] = df["title"].astype(str)
df["title_length"] = df["title"].str.len()

# %%
#for shortest title
print(df.loc[df["title_length"].idxmin(), "title"])
#for longest title
print(df.loc[df["title_length"].idxmax(), "title"])
#average title length
print(df["title_length"].mean())
# Out:
# Is that him?
# When NOT to use AI in your hackathon project with MLH winners Cindy Cui and Alison Co [Podcast #198]
# 60.451

# %%
#Plot distribution of title lengths 
df["title_length"].plot(kind="hist", bins=20, title="Title Length Distribution")
plt.xlabel("Title Length")
plt.tight_layout()
plt.show()

# %%
print("Total Unique Videos:", df["video_id"].nunique())
print("Date Range:", df["publish_date"].min(), "to", df["publish_date"].max())
# Out:
# Total Unique Videos: 1000
# Date Range: 2021-06-03 14:04:12+00:00 to 2026-03-04 13:29:25+00:00

# %%
df = df.head(350)
print(f"Dataset trimmed to {len(df)} rows")
# Out:
# Dataset trimmed to 350 rows

# %%
if 100 <= len(df) <= 350:
    print("Dataset size within recommended range ✅")
else:
    print("Dataset size outside recommended range ⚠")
# Out:
# Dataset size within recommended range ✅

# %%
df["title"] = df["title"].str.strip()
df["title"] = df["title"].str.replace("\n", " ", regex=False)

df.head()
# Out:
#       video_id                                              title  \
# 0  cw02dMpWStI  How to find good open source projects to contr...
# 1  0WjfKQdfeMU  NVIDIA-Certified Associate AI Infrastructure a...
# 2  ZldNCx4AvEM  Learn the basics of Git in 60 seconds with Bea...
# 3  E7o_WdfKszU  There's so much to learn - so how do you focus...
# 4  IBTx5aGj-6U  Build Your Own Video Sharing App – Loom Clone ...
#
#                publish_date  year  month  title_length
# 0 2026-03-04 13:29:25+00:00  2026      3            76
# 1 2026-03-04 11:00:02+00:00  2026      3            88
# 2 2026-03-03 13:05:25+00:00  2026      3            54
# 3 2026-03-02 13:17:28+00:00  2026      3            79
# 4 2026-03-02 11:00:33+00:00  2026      3            86

# %%
df.to_csv("cleaned_metadata.csv", index=False)
print("Cleaned dataset saved as cleaned_metadata.csv")
# Out:
# Cleaned dataset saved as cleaned_metadata.csv
